# %% [markdown]
# <a href="https://colab.research.google.com/github/Thrisha213/dav-lab/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
arr= np.array([10,20,30,40,50])
print("array:",arr)
# Out:
# array: [10 20 30 40 50]

# %%
print("maen:",arr.mean())
# Out:
# maen: 30.0

# %%
print("reshaped 2d:\n",arr.reshape(5,1))
# Out:
# reshaped 2d:
#  [[10]
#  [20]
#  [30]
#  [40]
#  [50]]

# %%
print("sliced(index 1 to 3);",arr[1:4])
# Out:
# sliced(index 1 to 3); [20 30 40]

# %%
data={'name':['seetha','ram','tulsi'],
      'age':['30','20','10'],
      'marks':[10,20,30]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      name age  marks
# 0  seetha  30     10
# 1     ram  20     20
# 2   tulsi  10     30

# %%
print('\nmarks column:\n',df['marks'])
# Out:
# marks column:
#  0    10
# 1    20
# 2    30
# Name: marks, dtype: int64

# %%
print('First two rows:\n',df.iloc[0:2])
print('Rows where marks greater than 75:\n',df[df['marks']>25])
# Out:
# First two rows:
#       name age  marks
# 0  seetha  30     10
# 1     ram  20     20
# Rows where marks greater than 75:
#      name age  marks
# 2  tulsi  10     30
